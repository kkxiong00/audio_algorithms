# %% [markdown]
# <a href="https://colab.research.google.com/github/kkxiong00/audio_algorithms/blob/main/helloworld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# this is hello world of this repo.

print("hello world");
# Out:
# hello world
